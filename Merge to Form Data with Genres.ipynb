# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data_w_artists.csv')

# %%
df.head(2)
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
#
#    key  liveness  loudness  mode                                      name  \
# 0   10    0.1510   -12.428     1               Singende Bataillone 1. Teil
# 1    8    0.0763   -28.454     1  Fantasiestücke, Op. 111: Più tosto lento
#
#    popularity release_date  speechiness    tempo  valence  year
# 0           0         1928       0.0506  118.469   0.7790  1928
# 1           0         1928       0.0462   83.972   0.0767  1928

# %%
df["artists"] = df["artists"].apply(eval)

# %%
tags = df['artists'].apply(pd.Series)

# %%
tags
# Out:
#                          0                  1    2    3    4    5    6    7   \
# 0           Carl Woitschach                NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1           Robert Schumann  Vladimir Horowitz  NaN  NaN  NaN  NaN  NaN  NaN
# 2       Seweryn Goszczyński                NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3          Francisco Canaro                NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4           Frédéric Chopin  Vladimir Horowitz  NaN  NaN  NaN  NaN  NaN  NaN
# ...                     ...                ...  ...  ...  ...  ...  ...  ...
# 169904           DripReport               Tyga  NaN  NaN  NaN  NaN  NaN  NaN
# 169905         Leon Bridges     Terrace Martin  NaN  NaN  NaN  NaN  NaN  NaN
# 169906                 Kygo          Oh Wonder  NaN  NaN  NaN  NaN  NaN  NaN
# 169907            Cash Cash       Andy Grammer  NaN  NaN  NaN  NaN  NaN  NaN
# 169908       Ingrid Andress                NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# ...

# %%
tags = tags.rename(columns = lambda x : 'tag_' + str(x))

# %%
tags = tags[['tag_0','tag_1']]

# %%
dff =pd.concat([df[:], tags[:]], axis=1)

# %%
dff.head(1)
# Out:
#    acousticness            artists  danceability  duration_ms  energy  \
# 0         0.995  [Carl Woitschach]         0.708       158648   0.195
#
#    explicit                      id  instrumentalness  key  liveness  ...  \
# 0         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563   10     0.151  ...
#
#    mode                         name popularity  release_date speechiness  \
# 0     1  Singende Bataillone 1. Teil          0          1928      0.0506
#
#      tempo  valence  year            tag_0 tag_1
# 0  118.469    0.779  1928  Carl Woitschach   NaN
#
# [1 rows x 21 columns]

# %%
tags = tags.rename(columns = {'tag_0': 'artists'})
dff = dff.drop(['tag_1'],axis=1)

# %%
dff = dff[['id','tag_0']]
dff = dff.rename(columns={'tag_0': 'artistind'})

# %%
dff.shape
# Out:
# (169909, 2)

# %%
dff.head(1)
# Out:
#                        id        artistind
# 0  6KbQ3uYMLKb5jDxLF7wYDD  Carl Woitschach

# %%
dwg = pd.read_csv("data_w_genres.csv")

# %%
dwg=dwg[['artists','genres']]

# %%
dwg = dwg.merge(dff, left_on ='artists',right_on='artistind')

# %%
dwg.head(1)
# Out:
#                    artists genres                      id  \
# 0  "Test for Victor Young"     []  6ivMXI6YMOPvsiUyTDIV7b
#
#                  artistind
# 0  "Test for Victor Young"

# %%
dwg = dwg.drop(['artistind'],axis=1)

# %%
dwg.head(1)
# Out:
#                    artists genres                      id
# 0  "Test for Victor Young"     []  6ivMXI6YMOPvsiUyTDIV7b

# %%
df1 = pd.read_csv('data.csv')

# %%
df1=df1.merge(dwg)

# %%
df1.to_csv("something.csv")

# %%
df1.head()
# Out:
#    acousticness                          artist_name  danceability  \
# 0         0.995                      Carl Woitschach         0.708
# 1         0.994  Robert Schumann & Vladimir Horowitz         0.379
# 2         0.604                  Seweryn Goszczyński         0.749
# 3         0.995                     Francisco Canaro         0.781
# 4         0.990  Frédéric Chopin & Vladimir Horowitz         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
#    key  liveness  ...  mode                                          title  \
# ...
